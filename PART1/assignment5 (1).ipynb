# %%
import random
import time
from collections import defaultdict

# ──────────────────────────────────────────
# SERVER SETUP
# ──────────────────────────────────────────

servers = [
    {"id": "Server1", "weight": 1, "connections": 0, "response_time": 0.1},
    {"id": "Server2", "weight": 2, "connections": 0, "response_time": 0.2},
    {"id": "Server3", "weight": 3, "connections": 0, "response_time": 0.15},
]

# ──────────────────────────────────────────
# ALGORITHMS
# ──────────────────────────────────────────

# 1. Round Robin

rr_index = 0

def round_robin(request_id):
    global rr_index
    server = servers[rr_index % len(servers)]
    rr_index += 1
    return server["id"]

# 2. Weighted Round Robin

wrr_sequence = []

for s in servers:
    wrr_sequence.extend([s["id"]] * s["weight"])

wrr_index = 0

def weighted_round_robin(request_id):
    global wrr_index
    server = wrr_sequence[wrr_index % len(wrr_sequence)]
    wrr_index += 1
    return server

# 3. Least Connections

def least_connections(request_id):
    server = min(servers, key=lambda s: s["connections"])
    server["connections"] += 1
    return server["id"]

# 4. Least Response Time

def least_response_time(request_id):
    server = min(servers, key=lambda s: s["response_time"])
    return server["id"]

# 5. IP Hashing

def ip_hashing(client_ip):
    hash_val = sum(int(part) for part in client_ip.split("."))
    server = servers[hash_val % len(servers)]
    return server["id"]

# ──────────────────────────────────────────
# SIMULATE REQUESTS
# ──────────────────────────────────────────

def simulate(algorithm_name, algorithm_func, num_requests=10):

    print(f"\n{'='*45}")
    print(f" Algorithm: {algorithm_name}")
    print(f"{'='*45}")

    distribution = defaultdict(int)

    for i in range(1, num_requests + 1):

        client_ip = f"192.168.1.{random.randint(1, 20)}"

        if algorithm_name == "IP Hashing":
            assigned = algorithm_func(client_ip)
        else:
            assigned = algorithm_func(i)

        distribution[assigned] += 1

        print(f" Request {i:02d} | Client IP: {client_ip} → {assigned}")

    print(f"\n Distribution Summary:")

    for server, count in distribution.items():
        print(f" {server}: {count} requests")

# ──────────────────────────────────────────
# MAIN
# ──────────────────────────────────────────

if __name__ == "__main__":

    print("\n*** Load Balancing Simulation ***")

    print(f"Servers: {[s['id'] for s in servers]}")
    print(f"Weights: {[s['weight'] for s in servers]}")

    simulate("Round Robin", round_robin)

    simulate("Weighted Round Robin", weighted_round_robin)

    simulate("Least Connections", least_connections)

    simulate("Least Response Time", least_response_time)

    simulate("IP Hashing", ip_hashing)

    print("\n*** Simulation Complete ***\n")
# Out:
# *** Load Balancing Simulation ***
# Servers: ['Server1', 'Server2', 'Server3']
# Weights: [1, 2, 3]
#
# =============================================
#  Algorithm: Round Robin
# =============================================
#  Request 01 | Client IP: 192.168.1.17 → Server1
#  Request 02 | Client IP: 192.168.1.4 → Server2
#  Request 03 | Client IP: 192.168.1.13 → Server3
#  Request 04 | Client IP: 192.168.1.18 → Server1
#  Request 05 | Client IP: 192.168.1.18 → Server2
#  Request 06 | Client IP: 192.168.1.4 → Server3
#  Request 07 | Client IP: 192.168.1.2 → Server1
#  Request 08 | Client IP: 192.168.1.4 → Server2
#  Request 09 | Client IP: 192.168.1.11 → Server3
#  Request 10 | Client IP: 192.168.1.15 → Server1
#
#  Distribution Summary:
#  Server1: 4 requests
#  Server2: 3 requests
#  Server3: 3 requests
#
# =============================================
#  Algorithm: Weighted Round Robin
# =============================================
#  Request 01 | Client IP: 192.168.1.1 → Server1
#  Request 02 | Client IP: 192.168.1.1 → Server2
#  Request 03 | Client IP: 192.168.1.10 → Server2
#  Request 04 | Client IP: 192.168.1.14 → Server3
#  Request 05 | Client IP: 192.168.1.18 → Server3
#  Request 06 | Client IP: 192.168.1.9 → Server3
#  Request 07 | Client IP: 192.168.1.2 → Server1
#  Request 08 | Client IP: 192.168.1.7 → Server2
#  Request 09 | Client IP: 192.168.1.19 → Server2
#  Request 10 | Client IP: 192.168.1.15 → Server3
#
#  Distribution Summary:
#  Server1: 2 requests
#  Server2: 4 requests
#  Server3: 4 requests
#
# =============================================
#  Algorithm: Least Connections
# =============================================
#  Request 01 | Client IP: 192.168.1.1 → Server1
#  Request 02 | Client IP: 192.168.1.2 → Server2
#  Request 03 | Client IP: 192.168.1.17 → Server3
#  Request 04 | Client IP: 192.168.1.14 → Server1
#  Request 05 | Client IP: 192.168.1.16 → Server2
#  Request 06 | Client IP: 192.168.1.18 → Server3
#  Request 07 | Client IP: 192.168.1.9 → Server1
#  Request 08 | Client IP: 192.168.1.16 → Server2
#  Request 09 | Client IP: 192.168.1.11 → Server3
#  Request 10 | Client IP: 192.168.1.17 → Server1
#
#  Distribution Summary:
#  Server1: 4 requests
#  Server2: 3 requests
#  Server3: 3 requests
#
# =============================================
#  Algorithm: Least Response Time
# =============================================
#  Request 01 | Client IP: 192.168.1.5 → Server1
#  Request 02 | Client IP: 192.168.1.19 → Server1
#  Request 03 | Client IP: 192.168.1.12 → Server1
#  Request 04 | Client IP: 192.168.1.14 → Server1
#  Request 05 | Client IP: 192.168.1.13 → Server1
#  Request 06 | Client IP: 192.168.1.4 → Server1
#  Request 07 | Client IP: 192.168.1.13 → Server1
#  Request 08 | Client IP: 192.168.1.12 → Server1
#  Request 09 | Client IP: 192.168.1.7 → Server1
#  Request 10 | Client IP: 192.168.1.14 → Server1
#
#  Distribution Summary:
#  Server1: 10 requests
#
# =============================================
#  Algorithm: IP Hashing
# =============================================
#  Request 01 | Client IP: 192.168.1.11 → Server1
#  Request 02 | Client IP: 192.168.1.13 → Server3
#  Request 03 | Client IP: 192.168.1.14 → Server1
#  Request 04 | Client IP: 192.168.1.13 → Server3
#  Request 05 | Client IP: 192.168.1.12 → Server2
#  Request 06 | Client IP: 192.168.1.10 → Server3
#  Request 07 | Client IP: 192.168.1.7 → Server3
#  Request 08 | Client IP: 192.168.1.1 → Server3
#  Request 09 | Client IP: 192.168.1.2 → Server1
#  Request 10 | Client IP: 192.168.1.14 → Server1
#
#  Distribution Summary:
#  Server1: 4 requests
#  Server3: 5 requests
#  Server2: 1 requests
#
# *** Simulation Complete ***
